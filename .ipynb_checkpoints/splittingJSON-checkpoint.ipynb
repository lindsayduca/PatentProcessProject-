# %%
import json
path = '/Users/duca_l2/Desktop'
with open('2020.json') as infile:
  o = json.load(infile)
  chunkSize = 1000
  for i in xrange(0, len(o), chunkSize):
    with open('file_' + str(i//chunkSize) + '.json', 'w') as outfile:
      json.dump(o[i:i+chunkSize], outfile)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-8dabd369fded> in <module>
#       1 import json
# ----> 2 with open('file.json') as infile:
#       3   o = json.load(infile)
#       4   chunkSize = 1000
#       5   for i in xrange(0, len(o), chunkSize):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.json'
